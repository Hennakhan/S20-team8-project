# %% [markdown]
# ## Top 1 Top5 and Top 10 accuracies for 50 classes

# %% [markdown]
# ##### Random seed for 5-Fold

# %%
SEED = 42
from random import seed as py_seed
py_seed(SEED)
from numpy.random import seed as np_seed
np_seed(SEED)
from tensorflow import random as tf_random
tf_random.set_seed(SEED)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Activation, GlobalAveragePooling2D
from keras.optimizers import Adam, SGD, RMSprop
from keras.utils import np_utils
from keras.models import load_model
from keras.applications.mobilenet import MobileNet
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.applications.nasnet import NASNetMobile
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import random
from sklearn.model_selection import KFold, train_test_split
import pickle
from keras import backend as K
import keras
import tensorflow as tf
import functools

# %%
### Read 101 categories and randomely select 50 categories. Read data only from those folders.

# %%
# Data comes from here. This should contain a bunch of folders of classes, each containing examples
#DATA_PATH = Path('food-101-original-source/images')
DATA_PATH = Path('C:/Users/kheen/Documents/5850/food-101/food-101/images')
SAVE_PATH = '50_runs/'

# Get class (folder) names
classes = sorted([entry.name for entry in DATA_PATH.iterdir() if entry.is_dir()])

SPLIT = 50
random.shuffle(classes) # shuffle the classes 
classes = classes[:SPLIT]

# Load list of filenames and classes, and convert to numpy array to allow array slicing
# For k-fold validation
dataset = np.array([
    (f"{clazz}/{entry.name}", clazz)
    for clazz in classes
    for entry in (DATA_PATH / clazz).iterdir()
])

# %% [markdown]
# ### Labels

# %%
print(classes)
# Out:
# ['dumplings', 'bruschetta', 'paella', 'chicken_curry', 'pizza', 'poutine', 'chicken_quesadilla', 'foie_gras', 'hamburger', 'greek_salad', 'carrot_cake', 'onion_rings', 'ice_cream', 'peking_duck', 'seaweed_salad', 'fish_and_chips', 'pancakes', 'chicken_wings', 'grilled_salmon', 'baby_back_ribs', 'fried_rice', 'edamame', 'churros', 'falafel', 'caprese_salad', 'beet_salad', 'red_velvet_cake', 'french_fries', 'tuna_tartare', 'filet_mignon', 'spring_rolls', 'sashimi', 'guacamole', 'gnocchi', 'prime_rib', 'risotto', 'grilled_cheese_sandwich', 'lasagna', 'cheesecake', 'caesar_salad', 'lobster_roll_sandwich', 'ramen', 'scallops', 'eggs_benedict', 'frozen_yogurt', 'miso_soup', 'takoyaki', 'omelette', 'chocolate_cake', 'tiramisu']

# %%
# create data generators

# Rescale 0-255 to 0-1
RESCALE=1./255

# This type of data generator is used to train the model
train_datagen = ImageDataGenerator(
    rescale=RESCALE,
    # Factors used to control
    rotation_range=45,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.125,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.125,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images

)

# This type of generator is used to test the model
test_datagen = ImageDataGenerator(
    rescale=RESCALE,
)

# %% [markdown]
# ### Function for Top 10 accuracy

# %%
top10_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=10)

top10_acc.__name__ = 'top10_acc'

# %%
def create_model(input_shape, num_classes):
    
    # Base model, with weights pre-trained on ImageNet.
    base_model = NASNetMobile(input_shape, weights='imagenet', include_top=False)

    for layer in base_model.layers:
        layer.trainable = False

    model = Sequential()
    model.add(base_model)
    model.add(GlobalAveragePooling2D())
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    optimizer = RMSprop()

    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = optimizer,
        metrics = ['accuracy', 'top_k_categorical_accuracy',top10_acc]  # top1, top5 and top10 accuracies
    )
    
    return model

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# NASNet (Model)               (None, 7, 7, 1056)        4269716
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 1056)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1056)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                52850
# =================================================================
# Total params: 4,322,566
# Trainable params: 52,850
# Non-trainable params: 4,269,716
# _________________________________________________________________

# %%
# Image data generator settings
TARGET_SIZE = (224,224)
COLOR_MODE = "rgb"
BATCH_SIZE = 64
CLASS_MODE = "categorical"


# Training settings
NUM_FOLDS = 5
VALIDATION_SPLIT = 0.1
NUM_EPOCHS = 5

# Model settings
kf = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
results = []
cur_fold = 1

# saving classes used by this model
with open(SAVE_PATH+'classes_50.txt', 'w') as f:
    f.writelines("%s\n" % clss for clss in classes)

for train_index, test_index in kf.split(dataset):
    # Print a message
    print(f"Fold {cur_fold} of {NUM_FOLDS}")
    cur_fold += 1
    
    # Extract train dataset
    d_train = dataset[train_index]
    # Split train dataset to form train and validation dataset
    d_train, d_val = train_test_split(dataset, test_size = VALIDATION_SPLIT)
    
    # These are used to convert the filename,class pairs to dataframes
    FILENAME_COL = "filename"
    CLASS_COL = "class"
    COLUMNS = [FILENAME_COL, CLASS_COL]
    # Convert to dataframes
    d_train = pd.DataFrame(d_train, columns = COLUMNS)
    d_val = pd.DataFrame(d_val, columns = COLUMNS)
    
    # Create training data generators
    # Training image data generator
    train_it = train_datagen.flow_from_dataframe(
        d_train,
        directory = DATA_PATH,
        x_col = FILENAME_COL,
        y_col = CLASS_COL,
        target_size = TARGET_SIZE,
        color_mode = COLOR_MODE,
        batch_size = BATCH_SIZE,
        class_mode = CLASS_MODE,
        shuffle = True,
        seed = SEED
    )
    # Validation image data generator
    val_it = test_datagen.flow_from_dataframe(
        d_val,
        directory = DATA_PATH,
        x_col = FILENAME_COL,
        y_col = CLASS_COL,
        target_size = TARGET_SIZE,
        color_mode = COLOR_MODE,
        batch_size = BATCH_SIZE,
        class_mode = CLASS_MODE,
        shuffle = False,
    )
    
    # Perform training
    # Build the model
    input_shape = (*TARGET_SIZE,3)
    num_classes = len(classes)
    model = create_model(input_shape, num_classes)
    
    # Train the model
    history = model.fit(
        train_it,
        validation_data=val_it,
        epochs=NUM_EPOCHS,
        workers=6,
        max_queue_size=100,
        verbose=True
    )
    
    # Extract test dataset and convert to dataframe
    d_test = pd.DataFrame(dataset[test_index], columns = COLUMNS)
    # Create test image data generator
    test_it = test_datagen.flow_from_dataframe(
        d_test,
        directory = DATA_PATH,
        x_col = FILENAME_COL,
        y_col = CLASS_COL,
        target_size = TARGET_SIZE,
        color_mode = COLOR_MODE,
        batch_size = BATCH_SIZE,
        class_mode = CLASS_MODE,
        shuffle = False,
    )
    
    
    # Save history to a file 
    with open(SAVE_PATH+"history_50_"+str(cur_fold-1)+".pkl", 'wb') as file:
        pickle.dump(history, file)   
        
    # saving labels to a file (y_test)
    with open(SAVE_PATH+"y_test_50_"+str(cur_fold-1)+".pkl", 'wb') as file:
        pickle.dump(test_it.classes, file)

    # predict model
    y_predict = model.predict(test_it)
    
    # save it to a file (Y_predict)
    with open(SAVE_PATH+"y_predict_50_"+str(cur_fold-1)+".pkl", 'wb') as file:
        pickle.dump(y_predict, file)
    
    # Test
    fold_results = model.evaluate(test_it)
    results.append(fold_results)
    print(f"Results for current fold: {fold_results}")
# Out:
# Fold 1 of 5
# Found 45000 validated image filenames belonging to 50 classes.
# Found 5000 validated image filenames belonging to 50 classes.
# Epoch 1/5
# 704/704 [==============================] - 7905s 11s/step - loss: 2.8577 - accuracy: 0.2688 - top_k_categorical_accuracy: 0.5489 - top10_acc: 0.6919 - val_loss: 2.0151 - val_accuracy: 0.3918 - val_top_k_categorical_accuracy: 0.7068 - val_top10_acc: 0.8308
# Epoch 2/5
# 704/704 [==============================] - 7751s 11s/step - loss: 2.3386 - accuracy: 0.3824 - top_k_categorical_accuracy: 0.6895 - top10_acc: 0.8153 - val_loss: 1.7313 - val_accuracy: 0.4140 - val_top_k_categorical_accuracy: 0.7138 - val_top10_acc: 0.8358
# Epoch 3/5
# 704/704 [==============================] - 7466s 11s/step - loss: 2.2602 - accuracy: 0.4051 - top_k_categorical_accuracy: 0.7086 - top10_acc: 0.8312 - val_loss: 1.8460 - val_accuracy: 0.4300 - val_top_k_categorical_accuracy: 0.7314 - val_top10_acc: 0.8556
# Epoch 4/5
# 704/704 [==============================] - 5108s 7s/step - loss: 2.2196 - accuracy: 0.4187 - top_k_categorical_accuracy: 0.7214 - top10_acc: 0.8402 - val_loss: 1.5821 - val_accuracy: 0.4360 - val_top_k_categorical_accuracy: 0.7420 - val_top10_acc: 0.8590
# Epoch 5/5
# 704/704 [==============================] - 4808s 7s/step - loss: 2.1938 - accuracy: 0.4266 - top_k_categorical_accuracy: 0.7293 - top10_acc: 0.8451 - val_loss: 1.7624 - val_accuracy: 0.4348 - val_top_k_categorical_accuracy: 0.7438 - val_top10_acc: 0.8616
# Found 10000 validated image filenames belonging to 50 classes.
# 157/157 [==============================] - 974s 6s/step
# Results for current fold: [4.038442134857178, 0.4343999922275543, 0.7494000196456909, 0.864799976348877]
# Fold 2 of 5
# Found 45000 validated image filenames belonging to 50 classes.
# Found 5000 validated image filenames belonging to 50 classes.
# Epoch 1/5
# 704/704 [==============================] - 4846s 7s/step - loss: 2.8342 - accuracy: 0.2749 - top_k_categorical_accuracy: 0.5547 - top10_acc: 0.6990 - val_loss: 2.2675 - val_accuracy: 0.3890 - val_top_k_categorical_accuracy: 0.6922 - val_top10_acc: 0.8160
# Epoch 2/5
# 704/704 [==============================] - 4885s 7s/step - loss: 2.3331 - accuracy: 0.3861 - top_k_categorical_accuracy: 0.6910 - top10_acc: 0.8157 - val_loss: 1.9134 - val_accuracy: 0.4236 - val_top_k_categorical_accuracy: 0.7252 - val_top10_acc: 0.8450
# Epoch 3/5
# 704/704 [==============================] - 4963s 7s/step - loss: 2.2512 - accuracy: 0.4088 - top_k_categorical_accuracy: 0.7100 - top10_acc: 0.8306 - val_loss: 1.9222 - val_accuracy: 0.4250 - val_top_k_categorical_accuracy: 0.7380 - val_top10_acc: 0.8526
# Epoch 4/5
# 704/704 [==============================] - 5694s 8s/step - loss: 2.2225 - accuracy: 0.4151 - top_k_categorical_accuracy: 0.7208 - top10_acc: 0.8390 - val_loss: 1.7641 - val_accuracy: 0.4408 - val_top_k_categorical_accuracy: 0.7410 - val_top10_acc: 0.8540
# Epoch 5/5
# 704/704 [==============================] - 4921s 7s/step - loss: 2.2085 - accuracy: 0.4215 - top_k_categorical_accuracy: 0.7249 - top10_acc: 0.8443 - val_loss: 1.8948 - val_accuracy: 0.4422 - val_top_k_categorical_accuracy: 0.7510 - val_top10_acc: 0.8602
# Found 10000 validated image filenames belonging to 50 classes.
# 157/157 [==============================] - 998s 6s/step
# Results for current fold: [2.6262712478637695, 0.4472000002861023, 0.7497000098228455, 0.8682000041007996]
# Fold 3 of 5
# Found 45000 validated image filenames belonging to 50 classes.
# Found 5000 validated image filenames belonging to 50 classes.
# Epoch 1/5
# 704/704 [==============================] - 6429s 9s/step - loss: 2.8538 - accuracy: 0.2723 - top_k_categorical_accuracy: 0.5466 - top10_acc: 0.6921 - val_loss: 2.5102 - val_accuracy: 0.3864 - val_top_k_categorical_accuracy: 0.6960 - val_top10_acc: 0.8240
# Epoch 2/5
# 704/704 [==============================] - 6200s 9s/step - loss: 2.3297 - accuracy: 0.3842 - top_k_categorical_accuracy: 0.6903 - top10_acc: 0.8179 - val_loss: 2.4863 - val_accuracy: 0.4162 - val_top_k_categorical_accuracy: 0.7320 - val_top10_acc: 0.8526
# Epoch 3/5
# 704/704 [==============================] - 5451s 8s/step - loss: 2.2604 - accuracy: 0.4061 - top_k_categorical_accuracy: 0.7070 - top10_acc: 0.8326 - val_loss: 2.3525 - val_accuracy: 0.4290 - val_top_k_categorical_accuracy: 0.7490 - val_top10_acc: 0.8570
# Epoch 4/5
# 704/704 [==============================] - 7173s 10s/step - loss: 2.2221 - accuracy: 0.4171 - top_k_categorical_accuracy: 0.7209 - top10_acc: 0.8406 - val_loss: 2.4439 - val_accuracy: 0.4256 - val_top_k_categorical_accuracy: 0.7400 - val_top10_acc: 0.8592
# Epoch 5/5
# 704/704 [==============================] - 6107s 9s/step - loss: 2.2072 - accuracy: 0.4217 - top_k_categorical_accuracy: 0.7269 - top10_acc: 0.8444 - val_loss: 2.4931 - val_accuracy: 0.4328 - val_top_k_categorical_accuracy: 0.7512 - val_top10_acc: 0.8608
# Found 10000 validated image filenames belonging to 50 classes.
# 157/157 [==============================] - 1071s 7s/step
# Results for current fold: [4.185863018035889, 0.4348999857902527, 0.7473999857902527, 0.8658999800682068]
# Fold 4 of 5
# Found 45000 validated image filenames belonging to 50 classes.
# Found 5000 validated image filenames belonging to 50 classes.
# Epoch 1/5
# 704/704 [==============================] - 5345s 8s/step - loss: 2.8564 - accuracy: 0.2699 - top_k_categorical_accuracy: 0.5474 - top10_acc: 0.6910 - val_loss: 2.1873 - val_accuracy: 0.3818 - val_top_k_categorical_accuracy: 0.6824 - val_top10_acc: 0.8102
# Epoch 2/5
# 704/704 [==============================] - 5273s 7s/step - loss: 2.3370 - accuracy: 0.3844 - top_k_categorical_accuracy: 0.6902 - top10_acc: 0.8178 - val_loss: 2.4324 - val_accuracy: 0.4136 - val_top_k_categorical_accuracy: 0.7230 - val_top10_acc: 0.8420
# Epoch 3/5
# 704/704 [==============================] - 5268s 7s/step - loss: 2.2573 - accuracy: 0.4071 - top_k_categorical_accuracy: 0.7109 - top10_acc: 0.8324 - val_loss: 2.3074 - val_accuracy: 0.4246 - val_top_k_categorical_accuracy: 0.7272 - val_top10_acc: 0.8472
# Epoch 4/5
# 704/704 [==============================] - 5267s 7s/step - loss: 2.2101 - accuracy: 0.4197 - top_k_categorical_accuracy: 0.7226 - top10_acc: 0.8413 - val_loss: 2.2429 - val_accuracy: 0.4374 - val_top_k_categorical_accuracy: 0.7422 - val_top10_acc: 0.8512
# Epoch 5/5
# 704/704 [==============================] - 5282s 8s/step - loss: 2.2093 - accuracy: 0.4219 - top_k_categorical_accuracy: 0.7246 - top10_acc: 0.8422 - val_loss: 2.0775 - val_accuracy: 0.4282 - val_top_k_categorical_accuracy: 0.7300 - val_top10_acc: 0.8548
# Found 10000 validated image filenames belonging to 50 classes.
# 157/157 [==============================] - 1091s 7s/step
# Results for current fold: [3.2576963901519775, 0.4325999915599823, 0.7455000281333923, 0.8607000112533569]
# Fold 5 of 5
# Found 45000 validated image filenames belonging to 50 classes.
# Found 5000 validated image filenames belonging to 50 classes.
# Epoch 1/5
# 704/704 [==============================] - 5466s 8s/step - loss: 2.8602 - accuracy: 0.2680 - top_k_categorical_accuracy: 0.5490 - top10_acc: 0.6934 - val_loss: 1.9226 - val_accuracy: 0.3758 - val_top_k_categorical_accuracy: 0.6834 - val_top10_acc: 0.8158
# Epoch 2/5
# 704/704 [==============================] - 5263s 7s/step - loss: 2.3387 - accuracy: 0.3840 - top_k_categorical_accuracy: 0.6943 - top10_acc: 0.8179 - val_loss: 1.9508 - val_accuracy: 0.4146 - val_top_k_categorical_accuracy: 0.7174 - val_top10_acc: 0.8454
# Epoch 3/5
# 704/704 [==============================] - 5336s 8s/step - loss: 2.2455 - accuracy: 0.4091 - top_k_categorical_accuracy: 0.7144 - top10_acc: 0.8340 - val_loss: 1.8460 - val_accuracy: 0.4244 - val_top_k_categorical_accuracy: 0.7318 - val_top10_acc: 0.8518
# Epoch 4/5
# 704/704 [==============================] - 6698s 10s/step - loss: 2.2200 - accuracy: 0.4165 - top_k_categorical_accuracy: 0.7206 - top10_acc: 0.8401 - val_loss: 1.6104 - val_accuracy: 0.4394 - val_top_k_categorical_accuracy: 0.7472 - val_top10_acc: 0.8634
# Epoch 5/5
# 704/704 [==============================] - 6258s 9s/step - loss: 2.1993 - accuracy: 0.4252 - top_k_categorical_accuracy: 0.7275 - top10_acc: 0.8443 - val_loss: 1.7978 - val_accuracy: 0.4364 - val_top_k_categorical_accuracy: 0.7424 - val_top10_acc: 0.8604
# Found 10000 validated image filenames belonging to 50 classes.
# 157/157 [==============================] - 1268s 8s/step
# Results for current fold: [4.433753967285156, 0.4426000118255615, 0.7480000257492065, 0.8652999997138977]

# %%
plt.figure(1)

# summarize history for accuracy
plt.subplot(211) 
plt.plot(history.history['accuracy']) 
plt.plot(history.history['top_k_categorical_accuracy'])
plt.plot(history.history['top10_acc'])
plt.plot(history.history['val_accuracy']) 
plt.title('model accuracy') 
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Top 1', ' Top 5','Top 10' , 'val'], loc='upper left')

# summarize history for loss
plt.subplot(212) 
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout() 
plt.show()

# %%
y_pred = []
for i in y_predict:
    y_pred.append(np.argmax(i, axis=0))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
print(" Confusion Matrix ")
conf_mat = confusion_matrix(test_it.classes, y_pred)
fig, ax = plt.subplots(figsize=(50,50))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap ='YlGnBu',
            xticklabels=classes, yticklabels=classes)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
#  Confusion Matrix

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

results = confusion_matrix(test_it.classes, y_pred)
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(test_it.classes, y_pred))
print ('Report : ')
print (classification_report(test_it.classes, y_pred))
# Out:
# Confusion Matrix :
# [[160   0   0 ...   0   0   0]
#  [  4  17   4 ...   0   0   4]
#  [ 13   0  34 ...   0   0   0]
#  ...
#  [ 15   1   6 ...  39   0   0]
#  [ 18   0   0 ...   0  33   1]
#  [ 14   1   4 ...   1   0  13]]
# Accuracy Score : 0.4426
# Report :
#               precision    recall  f1-score   support
#
#            0       0.23      0.73      0.35       218
#            1       0.35      0.08      0.14       201
#            2       0.41      0.16      0.23       212
#            3       0.38      0.50      0.43       204
#            4       0.71      0.15      0.25       190
#            5       0.33      0.38      0.36       221
#            6       0.37      0.32      0.34       196
#            7       0.26      0.54      0.35       201
#            8       0.42      0.66      0.51       201
#            9       0.46      0.59      0.52       204
#           10       0.82      0.07      0.14       190
#           11       0.96      0.38      0.54       186
#           12       0.96      0.64      0.77       202
#           13       0.99      0.87      0.93       205
#           14       0.29      0.68      0.41       185
#           15       0.83      0.12      0.22       232
#           16       0.23      0.55      0.32       207
#           17       0.33      0.67      0.44       209
#           18       0.27      0.19      0.22       181
#           19       0.81      0.70      0.75       202
#           20       0.74      0.27      0.39       220
#           21       0.62      0.72      0.66       194
#           22       0.45      0.39      0.42       199
#           23       0.62      0.29      0.40       200
#           24       0.66      0.19      0.29       185
#           25       0.17      0.41      0.24       200
#           26       0.76      0.71      0.73       190
#           27       0.70      0.68      0.69       198
#           28       0.81      0.30      0.44       190
#           29       0.43      0.37      0.40       217
#           30       0.44      0.33      0.38       193
#           31       0.91      0.70      0.79       194
#           32       0.36      0.25      0.29       203
#           33       0.83      0.69      0.76       216
#           34       0.72      0.20      0.31       197
#           35       0.53      0.55      0.54       194
#           36       0.39      0.20      0.27       203
#           37       0.83      0.79      0.81       203
#           38       0.42      0.71      0.53       210
#           39       0.42      0.36      0.39       202
#           40       0.44      0.84      0.58       190
#           41       0.66      0.24      0.35       205
#           42       0.33      0.56      0.41       202
#           43       0.74      0.42      0.54       170
#           44       0.17      0.56      0.26       177
#           45       0.89      0.43      0.58       182
#           46       0.52      0.58      0.55       196
#           47       0.72      0.19      0.30       205
#           48       0.69      0.16      0.26       205
#           49       0.33      0.06      0.10       213
#
#     accuracy                           0.44     10000
#    macro avg       0.55      0.44      0.44     10000
# weighted avg       0.55      0.44      0.44     10000
